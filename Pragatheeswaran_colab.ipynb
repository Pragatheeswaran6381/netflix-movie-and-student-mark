# %%
import pandas as pd

# %%
netflix=pd.read_csv('/content/netflix_user_behavior_dataset.csv')
netflix.head(30)
# Out:
#     user_id  age  gender    country  account_age_months subscription_type  \
# 0   U100000   56    Male      India                  17          Standard
# 1   U100001   46  Female        USA                  20          Standard
# 2   U100002   32   Other        USA                  25             Basic
# 3   U100003   60    Male     Canada                  37          Standard
# 4   U100004   25    Male     Brazil                  23           Premium
# 5   U100005   38  Female     France                  23          Standard
# 6   U100006   56   Other     Brazil                  11             Basic
# 7   U100007   36   Other  Australia                  46          Standard
# 8   U100008   40  Female  Australia                  20             Basic
# 9   U100009   28  Female         UK                   7           Premium
# 10  U100010   28  Female     Brazil                  23          Standard
# 11  U100011   41   Other     France                  23             Basic
# ...

# %%
df = pd.DataFrame(netflix)
print(df)
# Out:
#        user_id  age  gender country  account_age_months subscription_type  \
# 0      U100000   56    Male   India                  17          Standard
# 1      U100001   46  Female     USA                  20          Standard
# 2      U100002   32   Other     USA                  25             Basic
# 3      U100003   60    Male  Canada                  37          Standard
# 4      U100004   25    Male  Brazil                  23           Premium
# ...        ...  ...     ...     ...                 ...               ...
# 49995  U149995   60  Female   Japan                  30          Standard
# 49996  U149996   46   Other  Brazil                  39          Standard
# 49997  U149997   19    Male      UK                  53             Basic
# 49998  U149998   43  Female      UK                  19          Standard
# 49999  U149999   28   Other   India                  35             Basic
#
#        monthly_fee payment_method primary_device  devices_used favorite_genre  \
# ...

# %%
print(netflix.isnull().sum())
# Out:
# user_id                      0
# age                          0
# gender                       0
# country                      0
# account_age_months           0
# subscription_type            0
# monthly_fee                  0
# payment_method               0
# primary_device               0
# devices_used                 0
# favorite_genre               0
# avg_watch_time_minutes       0
# watch_sessions_per_week      0
# binge_watch_sessions         0
# completion_rate              0
# rating_given                 0
# content_interactions         0
# recommendation_click_rate    0
# days_since_last_login        0
# churned                      0
# dtype: int64

# %%
print(netflix['gender'].value_counts())
print(netflix['country'].value_counts().head(5))
# Out:
# gender
# Female    16759
# Male      16737
# Other     16504
# Name: count, dtype: int64
# country
# Brazil     5116
# USA        5087
# India      5028
# Spain      5027
# Germany    5024
# Name: count, dtype: int64

# %%
print(netflix.count())
# Out:
# user_id                      50000
# age                          50000
# gender                       50000
# country                      50000
# account_age_months           50000
# subscription_type            50000
# monthly_fee                  50000
# payment_method               50000
# primary_device               50000
# devices_used                 50000
# favorite_genre               50000
# avg_watch_time_minutes       50000
# watch_sessions_per_week      50000
# binge_watch_sessions         50000
# completion_rate              50000
# rating_given                 50000
# content_interactions         50000
# recommendation_click_rate    50000
# days_since_last_login        50000
# churned                      50000
# dtype: int64

# %%
print(netflix['primary_device'].value_counts())
# Out:
# primary_device
# Mobile      12585
# Smart TV    12562
# Laptop      12509
# Tablet      12344
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.countplot(data=netflix, x='gender', palette='viridis')
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_1083/3149093391.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=netflix, x='gender', palette='viridis')

# %%
df.tail(5)
# Out:
#        user_id  age  gender country  account_age_months subscription_type  \
# 49995  U149995   60  Female   Japan                  30          Standard
# 49996  U149996   46   Other  Brazil                  39          Standard
# 49997  U149997   19    Male      UK                  53             Basic
# 49998  U149998   43  Female      UK                  19          Standard
# 49999  U149999   28   Other   India                  35             Basic
#
#        monthly_fee payment_method primary_device  devices_used favorite_genre  \
# 49995        15.99            UPI         Tablet             1    Documentary
# 49996        12.99         PayPal       Smart TV             3         Comedy
# 49997         7.99    Credit Card         Tablet             3       Thriller
# 49998         7.99         PayPal         Laptop             1       Thriller
# 49999        15.99         PayPal         Laptop             1         Comedy
#
# ...

# %%
import pandas as pd

# %%
import pandas as pd

# %%
student=pd.read_csv('/content/AI_Data.csv')
student.head(6)
# Out:
#    Unnamed: 0             Name       Roll No Program Branch  Semester  \
# 0           0   AAKASH PIPALDE  0403AL231001  B.Tech     AL         4
# 1           1     AAYUSH PATEL  0403AL231002  B.Tech     AL         4
# 2           3      ABIR SAXENA  0403AL231004  B.Tech     AL         4
# 3           4  AMEY BHOKARIKAR  0403AL231005  B.Tech     AL         4
# 4           7      ANTIM JAMLE  0403AL231008  B.Tech     AL         4
# 5           8       ARUN KHODE  0403AL231009  B.Tech     AL         4
#
#     Status    Session AL401- [T] AL402- [T] AL403- [P] AL404- [P] AL405- [P]  \
# 0  Regular  June-2025         C+          B          A          A          A
# 1  Regular  June-2025          B          B          B          B          B
# 2  Regular  June-2025          D          C          B          B          B
# 3  Regular  June-2025          C          B          A          A          A
# 4  Regular  June-2025          F         C+         B+         B+         B+
# ...

# %%
student.dtypes
# Out:
# Unnamed: 0              int64
# Name                   object
# Roll No                object
# Program                object
# Branch                 object
# Semester                int64
# Status                 object
# Session                object
# AL401- [T]             object
# AL402- [T]             object
# AL403- [P]             object
# AL404- [P]             object
# AL405- [P]             object
# AL406- [P]             object
# Result Description     object
# SGPA                  float64
# CGPA                  float64
# dtype: object

# %%
df = pd.DataFrame(student)
print(df)
# Out:
#     Unnamed: 0             Name       Roll No Program Branch  Semester  \
# 0            0   AAKASH PIPALDE  0403AL231001  B.Tech     AL         4
# 1            1     AAYUSH PATEL  0403AL231002  B.Tech     AL         4
# 2            3      ABIR SAXENA  0403AL231004  B.Tech     AL         4
# 3            4  AMEY BHOKARIKAR  0403AL231005  B.Tech     AL         4
# 4            7      ANTIM JAMLE  0403AL231008  B.Tech     AL         4
# ..         ...              ...           ...     ...    ...       ...
# 57          72     VISHAL PATEL  0403AL231073  B.Tech     AL         4
# 58          74   YASH GUJARATHI  0403AL231075  B.Tech     AL         4
# 59          75      YASH PATHAK  0403AL231076  B.Tech     AL         4
# 60          76     YASHAD SATHE  0403AL231077  B.Tech     AL         4
# 61          77  ZAID ALI SAIYED  0403AL231078  B.Tech     AL         4
#
#      Status    Session AL401- [T] AL402- [T] AL403- [P] AL404- [P] AL405- [P]  \
# ...

# %%
mark.tail(10)
# Out:
#      index  ParticipantID     name  G3   Pass  PredictedGrade  PredictedRank  \
# 846    846            106     Lisa   9  False               7              7
# 847    619            106  Michael   8  False               5              8
# 848      7            107     Lisa   6  False               9              7
# 849    551            107    Brian  13   True              12              4
# 850    589            107    Sarah  13   True              14              2
# 851     68            107     Anna   8  False              10              6
# 852    101            107   Oliver  17   True              14              3
# 853    518            107    David   8  False               7              8
# 854    111            107    Jenny  10   True              16              1
# 855    550            107  Michael  11   True              12              5
#
#     StereotypeActivation  Predicted_Pass_PassFailStrategy  \
# 846            CaseBased                            False
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0            0
# Name                  0
# Roll No               0
# Program               0
# Branch                0
# Semester              0
# Status                0
# Session               0
# AL401- [T]            0
# AL402- [T]            0
# AL403- [P]            0
# AL404- [P]            0
# AL405- [P]            0
# AL406- [P]            0
# Result Description    0
# SGPA                  0
# CGPA                  0
# dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# Unnamed: 0            62
# Name                  62
# Roll No               62
# Program               62
# Branch                62
# Semester              62
# Status                62
# Session               62
# AL401- [T]            62
# AL402- [T]            62
# AL403- [P]            62
# AL404- [P]            62
# AL405- [P]            62
# AL406- [P]            62
# Result Description    62
# SGPA                  62
# CGPA                  62
# dtype: int64

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 17)

# %%
df = df.drop(['], axis=1)
df.head(5)

# %%
student["Result Description"].mode()[0]
# Out:
# 'PASS'

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
student["Result Description"]=le.fit_transform(student["Result Description"])
student.head(6)
# Out:
#    Unnamed: 0             Name       Roll No Program Branch  Semester  \
# 0           0   AAKASH PIPALDE  0403AL231001  B.Tech     AL         4
# 1           1     AAYUSH PATEL  0403AL231002  B.Tech     AL         4
# 2           3      ABIR SAXENA  0403AL231004  B.Tech     AL         4
# 3           4  AMEY BHOKARIKAR  0403AL231005  B.Tech     AL         4
# 4           7      ANTIM JAMLE  0403AL231008  B.Tech     AL         4
# 5           8       ARUN KHODE  0403AL231009  B.Tech     AL         4
#
#     Status    Session AL401- [T] AL402- [T] AL403- [P] AL404- [P] AL405- [P]  \
# 0  Regular  June-2025         C+          B          A          A          A
# 1  Regular  June-2025          B          B          B          B          B
# 2  Regular  June-2025          D          C          B          B          B
# 3  Regular  June-2025          C          B          A          A          A
# 4  Regular  June-2025          F         C+         B+         B+         B+
# ...

# %%
x=student.drop
